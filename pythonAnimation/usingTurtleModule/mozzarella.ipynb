# %%
def printPattern(n):
    for i in range(0, n + 1):
        for j in range(0, i + 1):
            print("*"*j)

n = int(input("n = "))
printPattern(n)
# Out:
# n = 4
#
#
# *
#
# *
# **
#
# *
# **
# ***
#
# *
# **
# ***
# ****
