# %% [markdown]
# Name: Pranav Gopalkrishna

# %% [markdown]
# Register number: 1940223

# %% [markdown]
# ## Question 1

# %%
from pylab import plot, show, title, legend, xlabel, ylabel, axis

# %%
cityA = [40, 43, 41.5, 45, 44]
cityB = [41, 42, 41.8, 44, 43.7]

# %%
plot(range(1, 6), cityA, range(1, 6), cityB)
legend(["City A", "City B"], bbox_to_anchor = (0.9, 0.5))
title("Highest temperatures in the last 5 years")
xlabel("Year")
ylabel("Temperature")
show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# Original code...

# %%
def centimeters(num)
cm = num*100
print({0}meters = {1} cm.format(num,cm))
def kilometers(num)
km=num/1000
print({0}meters = {1} km.format(num,km))
if name == “main”:
num=input(“How many meters: ”)
num=float(num)
centimeters(num)
kilometer(num)
# Out:
#   File "<ipython-input-28-7afa82291670>", line 1
#     def centimeters(num)
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Corrected code...

# %%
def centimeters(num):
    cm = num*100
    print("{0} meters = {1} cm".format(num, cm))
def kilometers(num):
    km=num/1000
    print("{0} meters = {1} km".format(num,km))
num=input("How many meters: ")
num=float(num)
centimeters(num)
kilometers(num)
# Out:
# How many meters: 1035
# 1035.0 meters = 103500.0 cm
# 1035.0 meters = 1.035 km
